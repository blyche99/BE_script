# %%
import pandas as pd
import numpy as np
from datetime import datetime
from uszipcode import SearchEngine
import xlsxwriter

pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('dirty_census.xls')

df
# Out:
#             SSN FirstName  LastName Gender  MaritalStatusCode  BirthDate  \
# 0   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 1   999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 2   999-99-9999      Test  Employee      F                NaN        NaT
# 3   999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 4   009-99-9999      Test  Employee      M                NaN 1921-01-01
# 5   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 6   999-99-9999      Test  Employee      M                NaN 1921-01-01
# 7   099-99-9999      Test  Employee      F                NaN 1921-01-01
# 8   999-99-9999      Test  Employee      M                NaN 1921-01-01
# 9   999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 10  009-99-9999      Test  Employee    NaN                NaN        NaT
# 11  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 12  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 13  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 14  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 15  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 16  999-99-9999      Test  Employee      F                NaN        NaT
# 17  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 18  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 19  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 20  999-99-9999      Test  Employee    NaN                NaN        NaT
# 21  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 22  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 23  999-99-9999      Test  Employee      F                NaN        NaT
# 24  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 25  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 26  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 27  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 28  000-99-9999      Test  Employee      F                NaN 1921-01-01
# 29  999-99-9999      Test  Employee      M                NaN 1921-01-01
# ..          ...       ...       ...    ...                ...        ...
# 33  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 34  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 35  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 36  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 37  999-99-9999      Test  Employee      F                NaN        NaT
# 38  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 39  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 40  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 41  999-99-9999      Test  Employee    NaN                NaN        NaT
# 42  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 43  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 44  999-99-9999      Test  Employee    NaN                NaN        NaT
# 45  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 46  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 47  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 48  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 49  009-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 50  999-99-9999      Test  Employee      F                NaN        NaT
# 51  099-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 52  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 53  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 54  999-99-9999      Test  Employee    NaN                NaN        NaT
# 55  999-99-9999      Test  Employee    NaN                NaN        NaT
# 56  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 57  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 58  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 59  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 60  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
# 61  999-99-9999      Test  Employee      F                NaN        NaT
# 62  999-99-9999      Test  Employee    NaN                NaN 1921-01-01
#
#     EmployeeID  EmployeeEmail EmployeeCellPhone              EmployeeBranch  \
# 0       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 1       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 2       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 3       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 4       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 5       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 6       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 7       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 8       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 9       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 10      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 11      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 12      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 13      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 14      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 15      999999  test@test.com    (999)-999-9999                       Eagan
# 16      999999  test@test.com    (999)-999-9999                       Eagan
# 17      999999  test@test.com    (999)-999-9999                       Eagan
# 18      999999  test@test.com    (999)-999-9999                       Eagan
# 19      999999  test@test.com    (999)-999-9999                       Eagan
# 20      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 21      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 22      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 23      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 24      999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 25      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 26      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 27      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 28      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 29      999999  test@test.com    (999)-999-9999             Paramount, LLC.
# ..         ...            ...               ...                         ...
# 33      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 34      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 35      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 36      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 37      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 38      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 39      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 40      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 41      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 42      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 43      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 44      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 45      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 46      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 47      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 48      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 49      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 50      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 51      999999  test@test.com    (999)-999-9999      Santa Fe Springs, LLC.
# 52      999999  test@test.com    (999)-999-9999      Santa Fe Springs, LLC.
# 53      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 54      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 55      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 56      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 57      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 58      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 59      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 60      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 61      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 62      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
#
#    EmployeeBranchCode     Address1  City StateCode  ZipCode Status  \
# 0         Test Branch  999 Test St  Test        CA    99999      A
# 1         Test Branch  999 Test St  Test        CA    99999      A
# 2         Test Branch  999 Test St   NaN       NaN    97701      T
# 3         Test Branch  999 Test St  Test        CA    99999      A
# 4         Test Branch  999 Test St  Test        CA    99999      A
# 5         Test Branch  999 Test St  Test        CA    99999      A
# 6         Test Branch  999 Test St  Test        CA    99999      A
# 7         Test Branch  999 Test St  Test        CA    99999      A
# 8         Test Branch  999 Test St  Test        CA    99999      A
# 9         Test Branch  999 Test St  Test        CA    99999      A
# 10        Test Branch  999 Test St  Test        CA    99999      A
# 11        Test Branch  999 Test St  Test        CA    99999      A
# 12        Test Branch  999 Test St  Test        CA    99999      A
# 13        Test Branch  999 Test St  Test        CA    99999      A
# 14        Test Branch  999 Test St   NaN       NaN    97403      T
# 15        Test Branch  999 Test St  Test        CA    99999      A
# 16        Test Branch  999 Test St  Test        CA    99999      A
# 17        Test Branch  999 Test St  Test        CA    99999      A
# 18        Test Branch  999 Test St  Test        CA    99999      A
# 19        Test Branch  999 Test St  Test        CA    99999      A
# 20        Test Branch  999 Test St  Test        CA    99999      A
# 21        Test Branch  999 Test St   NaN       NaN    97402      A
# 22        Test Branch  999 Test St  Test        CA    99999      A
# 23        Test Branch  999 Test St  Test        CA    99999      A
# 24        Test Branch  999 Test St  Test        CA    99999      T
# 25        Test Branch  999 Test St  Test        CA    99999      A
# 26        Test Branch  999 Test St  Test        CA    99999      A
# 27        Test Branch  999 Test St  Test        CA    99999      T
# 28        Test Branch  999 Test St  Test        CA    99999      A
# 29        Test Branch  999 Test St  Test        CA    99999      A
# ..                ...          ...   ...       ...      ...    ...
# 33        Test Branch  999 Test St  Test        CA    99999      A
# 34        Test Branch  999 Test St  Test        CA    99999      A
# 35        Test Branch  999 Test St  Test        CA    99999      A
# 36        Test Branch  999 Test St  Test        CA    99999      A
# 37        Test Branch  999 Test St  Test        CA    99999      A
# 38        Test Branch  999 Test St   NaN       NaN    97703      A
# 39        Test Branch  999 Test St  Test        CA    99999      T
# 40        Test Branch  999 Test St  Test        CA    99999      A
# 41        Test Branch  999 Test St  Test        CA    99999      T
# 42        Test Branch  999 Test St  Test       Cal     2111      A
# 43        Test Branch  999 Test St  Test        CA    99999      A
# 44        Test Branch  999 Test St   NaN        CA    97701      T
# 45        Test Branch  999 Test St  Test        CA    99999      A
# 46        Test Branch  999 Test St  Test        CA    99999      A
# 47        Test Branch  999 Test St  Test        CA    99999      A
# 48        Test Branch  999 Test St  Test        CA    99999      A
# 49        Test Branch  999 Test St  Test        CA    99999      A
# 50        Test Branch  999 Test St  Test       NaN    97403      A
# 51        Test Branch  999 Test St  Test        CA    99999      A
# 52        Test Branch  999 Test St  Test        CA    99999      T
# 53        Test Branch  999 Test St  Test        CA    99999      A
# 54        Test Branch  999 Test St  Test        CA    99999      T
# 55        Test Branch  999 Test St  Test        CA    99999      T
# 56        Test Branch  999 Test St  Test        CA    99999      A
# 57        Test Branch  999 Test St  Test        CA    99999      A
# 58        Test Branch  999 Test St   NaN        CA    97701      A
# 59        Test Branch  999 Test St  Test        CA    99999      A
# 60        Test Branch  999 Test St  Test        CA    99999      A
# 61        Test Branch  999 Test St  Test       NaN    97403      A
# 62        Test Branch  999 Test St  Test        CA    99999      A
#
#    LastStatusDate LocationStateCode  ClassificationCode   HireDate  Salaried  \
# 0             NaT                CA                 NaN 2021-02-01       NaN
# 1             NaT                CA                 NaN 2021-02-01       NaN
# 2      2020-01-02                CA                 NaN 2021-02-01       NaN
# 3             NaT                CA                 NaN 2021-02-01       NaN
# 4             NaT                CA                 NaN 2021-02-01       NaN
# 5             NaT                CA                 NaN 2021-02-01       NaN
# 6             NaT                CA                 NaN 2021-02-01       NaN
# 7             NaT                CA                 NaN 2021-02-01       NaN
# 8             NaT                CA                 NaN 2021-02-01       NaN
# 9             NaT                CA                 NaN 2021-02-01       NaN
# 10            NaT                CA                 NaN 2021-02-01       NaN
# 11     2020-01-01                CA                 NaN 2021-02-01       NaN
# 12            NaT                CA                 NaN 2021-02-01       NaN
# 13            NaT                CA                 NaN 2021-02-01       NaN
# 14     2020-01-01                CA                 NaN 2021-02-01       NaN
# 15            NaT                CA                 NaN 2021-02-01       NaN
# 16            NaT                CA                 NaN 2021-02-01       NaN
# 17            NaT                CA                 NaN 2021-02-01       NaN
# 18            NaT                CA                 NaN 2021-02-01       NaN
# 19            NaT                CA                 NaN 2021-02-01       NaN
# 20            NaT                CA                 NaN 2021-02-01       NaN
# 21            NaT                CA                 NaN 2021-02-01       NaN
# 22            NaT                CA                 NaN 2021-02-01       NaN
# 23            NaT                CA                 NaN 2021-02-01       NaN
# 24            NaT                CA                 NaN 2021-02-01       NaN
# 25            NaT                CA                 NaN 2021-02-01       NaN
# 26            NaT                CA                 NaN 2021-02-01       NaN
# 27            NaT                CA                 NaN 2021-02-01       NaN
# 28            NaT                CA                 NaN 2021-02-01       NaN
# 29            NaT                CA                 NaN 2021-02-01       NaN
# ..            ...               ...                 ...        ...       ...
# 33            NaT                CA                 NaN 2021-02-01       NaN
# 34            NaT                CA                 NaN 2021-02-01       NaN
# 35            NaT                CA                 NaN 2021-02-01       NaN
# 36            NaT                CA                 NaN 2021-02-01       NaN
# 37            NaT                CA                 NaN 2021-02-01       NaN
# 38            NaT                CA                 NaN 2021-02-01       NaN
# 39            NaT                CA                 NaN 2021-02-01       NaN
# 40            NaT                CA                 NaN 2021-02-01       NaN
# 41            NaT                CA                 NaN 2021-02-01       NaN
# 42            NaT                CA                 NaN 2021-02-01       NaN
# 43            NaT                CA                 NaN 2021-02-01       NaN
# 44            NaT                CA                 NaN 2021-02-01       NaN
# 45     2020-01-01                CA                 NaN 2021-02-01       NaN
# 46            NaT                CA                 NaN 2021-02-01       NaN
# 47            NaT                CA                 NaN 2021-02-01       NaN
# 48            NaT                CA                 NaN 2021-02-01       NaN
# 49            NaT                CA                 NaN 2021-02-01       NaN
# 50            NaT                CA                 NaN 2021-02-01       NaN
# 51            NaT                CA                 NaN 2021-02-01       NaN
# 52            NaT                CA                 NaN 2021-02-01       NaN
# 53            NaT                CA                 NaN 2021-02-01       NaN
# 54            NaT                CA                 NaN 2021-02-01       NaN
# 55            NaT                CA                 NaN 2021-02-01       NaN
# 56     2020-01-01                CA                 NaN 2021-02-01       NaN
# 57            NaT                CA                 NaN 2021-02-01       NaN
# 58            NaT                CA                 NaN 2021-02-01       NaN
# 59            NaT                CA                 NaN 2021-02-01       NaN
# 60            NaT                CA                 NaN 2021-02-01       NaN
# 61            NaT                CA                 NaN 2021-02-01       NaN
# 62            NaT                CA                 NaN 2021-02-01       NaN
#
#     HourlyRate  AnnualPay PayCycle
# 0         14.5    4903.92   Weekly
# 1         14.5    4903.92   Weekly
# 2         14.5    4903.92   Weekly
# 3         14.5    4903.92   Weekly
# 4         14.5    4903.92   Weekly
# 5          NaN        NaN   Weekly
# 6         14.5    4903.92   Weekly
# 7         14.5    4903.92   Weekly
# 8         14.5    4903.92   Weekly
# 9         14.5    4903.92   Weekly
# 10        14.5    4903.92   Weekly
# 11        14.5    4903.92   Weekly
# 12         NaN        NaN   Weekly
# 13        14.5    4903.92   Weekly
# 14        14.5    4903.92   Weekly
# 15        14.5    4903.92   Weekly
# 16        14.5    4903.92   Weekly
# 17        14.5    4903.92   Weekly
# 18        14.5    4903.92   Weekly
# 19         NaN        NaN   Weekly
# 20        14.5    4903.92   Weekly
# 21        14.5    4903.92   Weekly
# 22        14.5    4903.92   Weekly
# 23        14.5    4903.92   Weekly
# 24        14.5    4903.92   Weekly
# 25        14.5    4903.92   Weekly
# 26        14.5    4903.92   Weekly
# 27        14.5    4903.92   Weekly
# 28        14.5    4903.92   Weekly
# 29         NaN        NaN   Weekly
# ..         ...        ...      ...
# 33        14.5    4903.92   Weekly
# 34        14.5    4903.92   Weekly
# 35         NaN        NaN   Weekly
# 36        14.5    4903.92   Weekly
# 37        14.5    4903.92   Weekly
# 38        14.5    4903.92   Weekly
# 39         NaN        NaN   Weekly
# 40        14.5    4903.92   Weekly
# 41         NaN        NaN   Weekly
# 42         NaN        NaN   Weekly
# 43        14.5    4903.92   Weekly
# 44         NaN        NaN   Weekly
# 45         NaN        NaN   Weekly
# 46        14.5    4903.92   Weekly
# 47        14.5    4903.92   Weekly
# 48         NaN        NaN   Weekly
# 49        14.5    4903.92   Weekly
# 50        14.5    4903.92   Weekly
# 51        14.5    4903.92   Weekly
# 52         NaN        NaN   Weekly
# 53        14.5    4903.92   Weekly
# 54         NaN        NaN   Weekly
# 55         NaN        NaN   Weekly
# 56         NaN        NaN   Weekly
# 57        14.5    4903.92   Weekly
# 58        14.5    4903.92   Weekly
# 59         NaN        NaN   Weekly
# 60        14.5    4903.92   Weekly
# 61        14.5    4903.92   Weekly
# 62        14.5    4903.92   Weekly
#
# [63 rows x 24 columns]

# %%
df_1 = df

df['Gender'] = df_1['Gender'].fillna('F')

df
# Out:
#             SSN FirstName  LastName Gender  MaritalStatusCode  BirthDate  \
# 0   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 1   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 2   999-99-9999      Test  Employee      F                NaN        NaT
# 3   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 4   009-99-9999      Test  Employee      M                NaN 1921-01-01
# 5   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 6   999-99-9999      Test  Employee      M                NaN 1921-01-01
# 7   099-99-9999      Test  Employee      F                NaN 1921-01-01
# 8   999-99-9999      Test  Employee      M                NaN 1921-01-01
# 9   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 10  009-99-9999      Test  Employee      F                NaN        NaT
# 11  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 12  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 13  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 14  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 15  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 16  999-99-9999      Test  Employee      F                NaN        NaT
# 17  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 18  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 19  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 20  999-99-9999      Test  Employee      F                NaN        NaT
# 21  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 22  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 23  999-99-9999      Test  Employee      F                NaN        NaT
# 24  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 25  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 26  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 27  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 28  000-99-9999      Test  Employee      F                NaN 1921-01-01
# 29  999-99-9999      Test  Employee      M                NaN 1921-01-01
# ..          ...       ...       ...    ...                ...        ...
# 33  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 34  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 35  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 36  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 37  999-99-9999      Test  Employee      F                NaN        NaT
# 38  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 39  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 40  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 41  999-99-9999      Test  Employee      F                NaN        NaT
# 42  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 43  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 44  999-99-9999      Test  Employee      F                NaN        NaT
# 45  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 46  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 47  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 48  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 49  009-99-9999      Test  Employee      F                NaN 1921-01-01
# 50  999-99-9999      Test  Employee      F                NaN        NaT
# 51  099-99-9999      Test  Employee      F                NaN 1921-01-01
# 52  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 53  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 54  999-99-9999      Test  Employee      F                NaN        NaT
# 55  999-99-9999      Test  Employee      F                NaN        NaT
# 56  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 57  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 58  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 59  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 60  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 61  999-99-9999      Test  Employee      F                NaN        NaT
# 62  999-99-9999      Test  Employee      F                NaN 1921-01-01
#
#     EmployeeID  EmployeeEmail EmployeeCellPhone              EmployeeBranch  \
# 0       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 1       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 2       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 3       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 4       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 5       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 6       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 7       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 8       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 9       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 10      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 11      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 12      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 13      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 14      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 15      999999  test@test.com    (999)-999-9999                       Eagan
# 16      999999  test@test.com    (999)-999-9999                       Eagan
# 17      999999  test@test.com    (999)-999-9999                       Eagan
# 18      999999  test@test.com    (999)-999-9999                       Eagan
# 19      999999  test@test.com    (999)-999-9999                       Eagan
# 20      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 21      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 22      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 23      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 24      999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 25      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 26      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 27      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 28      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 29      999999  test@test.com    (999)-999-9999             Paramount, LLC.
# ..         ...            ...               ...                         ...
# 33      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 34      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 35      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 36      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 37      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 38      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 39      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 40      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 41      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 42      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 43      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 44      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 45      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 46      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 47      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 48      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 49      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 50      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 51      999999  test@test.com    (999)-999-9999      Santa Fe Springs, LLC.
# 52      999999  test@test.com    (999)-999-9999      Santa Fe Springs, LLC.
# 53      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 54      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 55      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 56      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 57      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 58      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 59      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 60      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 61      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 62      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
#
#    EmployeeBranchCode     Address1  City StateCode  ZipCode Status  \
# 0         Test Branch  999 Test St  Test        CA    99999      A
# 1         Test Branch  999 Test St  Test        CA    99999      A
# 2         Test Branch  999 Test St   NaN       NaN    97701      T
# 3         Test Branch  999 Test St  Test        CA    99999      A
# 4         Test Branch  999 Test St  Test        CA    99999      A
# 5         Test Branch  999 Test St  Test        CA    99999      A
# 6         Test Branch  999 Test St  Test        CA    99999      A
# 7         Test Branch  999 Test St  Test        CA    99999      A
# 8         Test Branch  999 Test St  Test        CA    99999      A
# 9         Test Branch  999 Test St  Test        CA    99999      A
# 10        Test Branch  999 Test St  Test        CA    99999      A
# 11        Test Branch  999 Test St  Test        CA    99999      A
# 12        Test Branch  999 Test St  Test        CA    99999      A
# 13        Test Branch  999 Test St  Test        CA    99999      A
# 14        Test Branch  999 Test St   NaN       NaN    97403      T
# 15        Test Branch  999 Test St  Test        CA    99999      A
# 16        Test Branch  999 Test St  Test        CA    99999      A
# 17        Test Branch  999 Test St  Test        CA    99999      A
# 18        Test Branch  999 Test St  Test        CA    99999      A
# 19        Test Branch  999 Test St  Test        CA    99999      A
# 20        Test Branch  999 Test St  Test        CA    99999      A
# 21        Test Branch  999 Test St   NaN       NaN    97402      A
# 22        Test Branch  999 Test St  Test        CA    99999      A
# 23        Test Branch  999 Test St  Test        CA    99999      A
# 24        Test Branch  999 Test St  Test        CA    99999      T
# 25        Test Branch  999 Test St  Test        CA    99999      A
# 26        Test Branch  999 Test St  Test        CA    99999      A
# 27        Test Branch  999 Test St  Test        CA    99999      T
# 28        Test Branch  999 Test St  Test        CA    99999      A
# 29        Test Branch  999 Test St  Test        CA    99999      A
# ..                ...          ...   ...       ...      ...    ...
# 33        Test Branch  999 Test St  Test        CA    99999      A
# 34        Test Branch  999 Test St  Test        CA    99999      A
# 35        Test Branch  999 Test St  Test        CA    99999      A
# 36        Test Branch  999 Test St  Test        CA    99999      A
# 37        Test Branch  999 Test St  Test        CA    99999      A
# 38        Test Branch  999 Test St   NaN       NaN    97703      A
# 39        Test Branch  999 Test St  Test        CA    99999      T
# 40        Test Branch  999 Test St  Test        CA    99999      A
# 41        Test Branch  999 Test St  Test        CA    99999      T
# 42        Test Branch  999 Test St  Test       Cal     2111      A
# 43        Test Branch  999 Test St  Test        CA    99999      A
# 44        Test Branch  999 Test St   NaN        CA    97701      T
# 45        Test Branch  999 Test St  Test        CA    99999      A
# 46        Test Branch  999 Test St  Test        CA    99999      A
# 47        Test Branch  999 Test St  Test        CA    99999      A
# 48        Test Branch  999 Test St  Test        CA    99999      A
# 49        Test Branch  999 Test St  Test        CA    99999      A
# 50        Test Branch  999 Test St  Test       NaN    97403      A
# 51        Test Branch  999 Test St  Test        CA    99999      A
# 52        Test Branch  999 Test St  Test        CA    99999      T
# 53        Test Branch  999 Test St  Test        CA    99999      A
# 54        Test Branch  999 Test St  Test        CA    99999      T
# 55        Test Branch  999 Test St  Test        CA    99999      T
# 56        Test Branch  999 Test St  Test        CA    99999      A
# 57        Test Branch  999 Test St  Test        CA    99999      A
# 58        Test Branch  999 Test St   NaN        CA    97701      A
# 59        Test Branch  999 Test St  Test        CA    99999      A
# 60        Test Branch  999 Test St  Test        CA    99999      A
# 61        Test Branch  999 Test St  Test       NaN    97403      A
# 62        Test Branch  999 Test St  Test        CA    99999      A
#
#    LastStatusDate LocationStateCode  ClassificationCode   HireDate  Salaried  \
# 0             NaT                CA                 NaN 2021-02-01       NaN
# 1             NaT                CA                 NaN 2021-02-01       NaN
# 2      2020-01-02                CA                 NaN 2021-02-01       NaN
# 3             NaT                CA                 NaN 2021-02-01       NaN
# 4             NaT                CA                 NaN 2021-02-01       NaN
# 5             NaT                CA                 NaN 2021-02-01       NaN
# 6             NaT                CA                 NaN 2021-02-01       NaN
# 7             NaT                CA                 NaN 2021-02-01       NaN
# 8             NaT                CA                 NaN 2021-02-01       NaN
# 9             NaT                CA                 NaN 2021-02-01       NaN
# 10            NaT                CA                 NaN 2021-02-01       NaN
# 11     2020-01-01                CA                 NaN 2021-02-01       NaN
# 12            NaT                CA                 NaN 2021-02-01       NaN
# 13            NaT                CA                 NaN 2021-02-01       NaN
# 14     2020-01-01                CA                 NaN 2021-02-01       NaN
# 15            NaT                CA                 NaN 2021-02-01       NaN
# 16            NaT                CA                 NaN 2021-02-01       NaN
# 17            NaT                CA                 NaN 2021-02-01       NaN
# 18            NaT                CA                 NaN 2021-02-01       NaN
# 19            NaT                CA                 NaN 2021-02-01       NaN
# 20            NaT                CA                 NaN 2021-02-01       NaN
# 21            NaT                CA                 NaN 2021-02-01       NaN
# 22            NaT                CA                 NaN 2021-02-01       NaN
# 23            NaT                CA                 NaN 2021-02-01       NaN
# 24            NaT                CA                 NaN 2021-02-01       NaN
# 25            NaT                CA                 NaN 2021-02-01       NaN
# 26            NaT                CA                 NaN 2021-02-01       NaN
# 27            NaT                CA                 NaN 2021-02-01       NaN
# 28            NaT                CA                 NaN 2021-02-01       NaN
# 29            NaT                CA                 NaN 2021-02-01       NaN
# ..            ...               ...                 ...        ...       ...
# 33            NaT                CA                 NaN 2021-02-01       NaN
# 34            NaT                CA                 NaN 2021-02-01       NaN
# 35            NaT                CA                 NaN 2021-02-01       NaN
# 36            NaT                CA                 NaN 2021-02-01       NaN
# 37            NaT                CA                 NaN 2021-02-01       NaN
# 38            NaT                CA                 NaN 2021-02-01       NaN
# 39            NaT                CA                 NaN 2021-02-01       NaN
# 40            NaT                CA                 NaN 2021-02-01       NaN
# 41            NaT                CA                 NaN 2021-02-01       NaN
# 42            NaT                CA                 NaN 2021-02-01       NaN
# 43            NaT                CA                 NaN 2021-02-01       NaN
# 44            NaT                CA                 NaN 2021-02-01       NaN
# 45     2020-01-01                CA                 NaN 2021-02-01       NaN
# 46            NaT                CA                 NaN 2021-02-01       NaN
# 47            NaT                CA                 NaN 2021-02-01       NaN
# 48            NaT                CA                 NaN 2021-02-01       NaN
# 49            NaT                CA                 NaN 2021-02-01       NaN
# 50            NaT                CA                 NaN 2021-02-01       NaN
# 51            NaT                CA                 NaN 2021-02-01       NaN
# 52            NaT                CA                 NaN 2021-02-01       NaN
# 53            NaT                CA                 NaN 2021-02-01       NaN
# 54            NaT                CA                 NaN 2021-02-01       NaN
# 55            NaT                CA                 NaN 2021-02-01       NaN
# 56     2020-01-01                CA                 NaN 2021-02-01       NaN
# 57            NaT                CA                 NaN 2021-02-01       NaN
# 58            NaT                CA                 NaN 2021-02-01       NaN
# 59            NaT                CA                 NaN 2021-02-01       NaN
# 60            NaT                CA                 NaN 2021-02-01       NaN
# 61            NaT                CA                 NaN 2021-02-01       NaN
# 62            NaT                CA                 NaN 2021-02-01       NaN
#
#     HourlyRate  AnnualPay PayCycle
# 0         14.5    4903.92   Weekly
# 1         14.5    4903.92   Weekly
# 2         14.5    4903.92   Weekly
# 3         14.5    4903.92   Weekly
# 4         14.5    4903.92   Weekly
# 5          NaN        NaN   Weekly
# 6         14.5    4903.92   Weekly
# 7         14.5    4903.92   Weekly
# 8         14.5    4903.92   Weekly
# 9         14.5    4903.92   Weekly
# 10        14.5    4903.92   Weekly
# 11        14.5    4903.92   Weekly
# 12         NaN        NaN   Weekly
# 13        14.5    4903.92   Weekly
# 14        14.5    4903.92   Weekly
# 15        14.5    4903.92   Weekly
# 16        14.5    4903.92   Weekly
# 17        14.5    4903.92   Weekly
# 18        14.5    4903.92   Weekly
# 19         NaN        NaN   Weekly
# 20        14.5    4903.92   Weekly
# 21        14.5    4903.92   Weekly
# 22        14.5    4903.92   Weekly
# 23        14.5    4903.92   Weekly
# 24        14.5    4903.92   Weekly
# 25        14.5    4903.92   Weekly
# 26        14.5    4903.92   Weekly
# 27        14.5    4903.92   Weekly
# 28        14.5    4903.92   Weekly
# 29         NaN        NaN   Weekly
# ..         ...        ...      ...
# 33        14.5    4903.92   Weekly
# 34        14.5    4903.92   Weekly
# 35         NaN        NaN   Weekly
# 36        14.5    4903.92   Weekly
# 37        14.5    4903.92   Weekly
# 38        14.5    4903.92   Weekly
# 39         NaN        NaN   Weekly
# 40        14.5    4903.92   Weekly
# 41         NaN        NaN   Weekly
# 42         NaN        NaN   Weekly
# 43        14.5    4903.92   Weekly
# 44         NaN        NaN   Weekly
# 45         NaN        NaN   Weekly
# 46        14.5    4903.92   Weekly
# 47        14.5    4903.92   Weekly
# 48         NaN        NaN   Weekly
# 49        14.5    4903.92   Weekly
# 50        14.5    4903.92   Weekly
# 51        14.5    4903.92   Weekly
# 52         NaN        NaN   Weekly
# 53        14.5    4903.92   Weekly
# 54         NaN        NaN   Weekly
# 55         NaN        NaN   Weekly
# 56         NaN        NaN   Weekly
# 57        14.5    4903.92   Weekly
# 58        14.5    4903.92   Weekly
# 59         NaN        NaN   Weekly
# 60        14.5    4903.92   Weekly
# 61        14.5    4903.92   Weekly
# 62        14.5    4903.92   Weekly
#
# [63 rows x 24 columns]

# %%
df['Gender'] = df['Gender'].fillna('F')

df
# Out:
#             SSN FirstName  LastName Gender  MaritalStatusCode  BirthDate  \
# 0   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 1   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 2   999-99-9999      Test  Employee      F                NaN        NaT
# 3   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 4   009-99-9999      Test  Employee      M                NaN 1921-01-01
# 5   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 6   999-99-9999      Test  Employee      M                NaN 1921-01-01
# 7   099-99-9999      Test  Employee      F                NaN 1921-01-01
# 8   999-99-9999      Test  Employee      M                NaN 1921-01-01
# 9   999-99-9999      Test  Employee      F                NaN 1921-01-01
# 10  009-99-9999      Test  Employee      F                NaN        NaT
# 11  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 12  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 13  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 14  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 15  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 16  999-99-9999      Test  Employee      F                NaN        NaT
# 17  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 18  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 19  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 20  999-99-9999      Test  Employee      F                NaN        NaT
# 21  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 22  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 23  999-99-9999      Test  Employee      F                NaN        NaT
# 24  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 25  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 26  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 27  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 28  000-99-9999      Test  Employee      F                NaN 1921-01-01
# 29  999-99-9999      Test  Employee      M                NaN 1921-01-01
# ..          ...       ...       ...    ...                ...        ...
# 33  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 34  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 35  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 36  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 37  999-99-9999      Test  Employee      F                NaN        NaT
# 38  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 39  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 40  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 41  999-99-9999      Test  Employee      F                NaN        NaT
# 42  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 43  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 44  999-99-9999      Test  Employee      F                NaN        NaT
# 45  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 46  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 47  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 48  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 49  009-99-9999      Test  Employee      F                NaN 1921-01-01
# 50  999-99-9999      Test  Employee      F                NaN        NaT
# 51  099-99-9999      Test  Employee      F                NaN 1921-01-01
# 52  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 53  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 54  999-99-9999      Test  Employee      F                NaN        NaT
# 55  999-99-9999      Test  Employee      F                NaN        NaT
# 56  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 57  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 58  999-99-9999      Test  Employee      M                NaN 1921-01-01
# 59  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 60  999-99-9999      Test  Employee      F                NaN 1921-01-01
# 61  999-99-9999      Test  Employee      F                NaN        NaT
# 62  999-99-9999      Test  Employee      F                NaN 1921-01-01
#
#     EmployeeID  EmployeeEmail EmployeeCellPhone              EmployeeBranch  \
# 0       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 1       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 2       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 3       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 4       999999  test@test.com    (999)-999-9999              Commerce, Inc.
# 5       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 6       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 7       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 8       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 9       999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 10      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 11      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 12      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 13      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 14      999999  test@test.com    (999)-999-9999              Commerce, LLC.
# 15      999999  test@test.com    (999)-999-9999                       Eagan
# 16      999999  test@test.com    (999)-999-9999                       Eagan
# 17      999999  test@test.com    (999)-999-9999                       Eagan
# 18      999999  test@test.com    (999)-999-9999                       Eagan
# 19      999999  test@test.com    (999)-999-9999                       Eagan
# 20      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 21      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 22      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 23      999999  test@test.com    (999)-999-9999      Internal Payroll, LLC.
# 24      999999  test@test.com    (999)-999-9999      Internal Payroll, Inc.
# 25      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 26      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 27      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 28      999999  test@test.com    (999)-999-9999             Paramount, Inc.
# 29      999999  test@test.com    (999)-999-9999             Paramount, LLC.
# ..         ...            ...               ...                         ...
# 33      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 34      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 35      999999  test@test.com    (999)-999-9999             Riverside, Inc.
# 36      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 37      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 38      999999  test@test.com    (999)-999-9999             Riverside, LLC.
# 39      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 40      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 41      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 42      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 43      999999  test@test.com    (999)-999-9999             Santa Ana, Inc.
# 44      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 45      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 46      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 47      999999  test@test.com    (999)-999-9999             Santa Ana, LLC.
# 48      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 49      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 50      999999  test@test.com    (999)-999-9999      Santa Fe Springs, Inc.
# 51      999999  test@test.com    (999)-999-9999      Santa Fe Springs, LLC.
# 52      999999  test@test.com    (999)-999-9999      Santa Fe Springs, LLC.
# 53      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 54      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 55      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 56      999999  test@test.com    (999)-999-9999  SkillSet Group Inc - Oasis
# 57      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 58      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 59      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 60      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 61      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
# 62      999999  test@test.com    (999)-999-9999  SkillSet Group LLC - Oasis
#
#    EmployeeBranchCode     Address1  City StateCode  ZipCode Status  \
# 0         Test Branch  999 Test St  Test        CA    99999      A
# 1         Test Branch  999 Test St  Test        CA    99999      A
# 2         Test Branch  999 Test St   NaN       NaN    97701      T
# 3         Test Branch  999 Test St  Test        CA    99999      A
# 4         Test Branch  999 Test St  Test        CA    99999      A
# 5         Test Branch  999 Test St  Test        CA    99999      A
# 6         Test Branch  999 Test St  Test        CA    99999      A
# 7         Test Branch  999 Test St  Test        CA    99999      A
# 8         Test Branch  999 Test St  Test        CA    99999      A
# 9         Test Branch  999 Test St  Test        CA    99999      A
# 10        Test Branch  999 Test St  Test        CA    99999      A
# 11        Test Branch  999 Test St  Test        CA    99999      A
# 12        Test Branch  999 Test St  Test        CA    99999      A
# 13        Test Branch  999 Test St  Test        CA    99999      A
# 14        Test Branch  999 Test St   NaN       NaN    97403      T
# 15        Test Branch  999 Test St  Test        CA    99999      A
# 16        Test Branch  999 Test St  Test        CA    99999      A
# 17        Test Branch  999 Test St  Test        CA    99999      A
# 18        Test Branch  999 Test St  Test        CA    99999      A
# 19        Test Branch  999 Test St  Test        CA    99999      A
# 20        Test Branch  999 Test St  Test        CA    99999      A
# 21        Test Branch  999 Test St   NaN       NaN    97402      A
# 22        Test Branch  999 Test St  Test        CA    99999      A
# 23        Test Branch  999 Test St  Test        CA    99999      A
# 24        Test Branch  999 Test St  Test        CA    99999      T
# 25        Test Branch  999 Test St  Test        CA    99999      A
# 26        Test Branch  999 Test St  Test        CA    99999      A
# 27        Test Branch  999 Test St  Test        CA    99999      T
# 28        Test Branch  999 Test St  Test        CA    99999      A
# 29        Test Branch  999 Test St  Test        CA    99999      A
# ..                ...          ...   ...       ...      ...    ...
# 33        Test Branch  999 Test St  Test        CA    99999      A
# 34        Test Branch  999 Test St  Test        CA    99999      A
# 35        Test Branch  999 Test St  Test        CA    99999      A
# 36        Test Branch  999 Test St  Test        CA    99999      A
# 37        Test Branch  999 Test St  Test        CA    99999      A
# 38        Test Branch  999 Test St   NaN       NaN    97703      A
# 39        Test Branch  999 Test St  Test        CA    99999      T
# 40        Test Branch  999 Test St  Test        CA    99999      A
# 41        Test Branch  999 Test St  Test        CA    99999      T
# 42        Test Branch  999 Test St  Test       Cal     2111      A
# 43        Test Branch  999 Test St  Test        CA    99999      A
# 44        Test Branch  999 Test St   NaN        CA    97701      T
# 45        Test Branch  999 Test St  Test        CA    99999      A
# 46        Test Branch  999 Test St  Test        CA    99999      A
# 47        Test Branch  999 Test St  Test        CA    99999      A
# 48        Test Branch  999 Test St  Test        CA    99999      A
# 49        Test Branch  999 Test St  Test        CA    99999      A
# 50        Test Branch  999 Test St  Test       NaN    97403      A
# 51        Test Branch  999 Test St  Test        CA    99999      A
# 52        Test Branch  999 Test St  Test        CA    99999      T
# 53        Test Branch  999 Test St  Test        CA    99999      A
# 54        Test Branch  999 Test St  Test        CA    99999      T
# 55        Test Branch  999 Test St  Test        CA    99999      T
# 56        Test Branch  999 Test St  Test        CA    99999      A
# 57        Test Branch  999 Test St  Test        CA    99999      A
# 58        Test Branch  999 Test St   NaN        CA    97701      A
# 59        Test Branch  999 Test St  Test        CA    99999      A
# 60        Test Branch  999 Test St  Test        CA    99999      A
# 61        Test Branch  999 Test St  Test       NaN    97403      A
# 62        Test Branch  999 Test St  Test        CA    99999      A
#
#    LastStatusDate LocationStateCode  ClassificationCode   HireDate  Salaried  \
# 0             NaT                CA                 NaN 2021-02-01       NaN
# 1             NaT                CA                 NaN 2021-02-01       NaN
# 2      2020-01-02                CA                 NaN 2021-02-01       NaN
# 3             NaT                CA                 NaN 2021-02-01       NaN
# 4             NaT                CA                 NaN 2021-02-01       NaN
# 5             NaT                CA                 NaN 2021-02-01       NaN
# 6             NaT                CA                 NaN 2021-02-01       NaN
# 7             NaT                CA                 NaN 2021-02-01       NaN
# 8             NaT                CA                 NaN 2021-02-01       NaN
# 9             NaT                CA                 NaN 2021-02-01       NaN
# 10            NaT                CA                 NaN 2021-02-01       NaN
# 11     2020-01-01                CA                 NaN 2021-02-01       NaN
# 12            NaT                CA                 NaN 2021-02-01       NaN
# 13            NaT                CA                 NaN 2021-02-01       NaN
# 14     2020-01-01                CA                 NaN 2021-02-01       NaN
# 15            NaT                CA                 NaN 2021-02-01       NaN
# 16            NaT                CA                 NaN 2021-02-01       NaN
# 17            NaT                CA                 NaN 2021-02-01       NaN
# 18            NaT                CA                 NaN 2021-02-01       NaN
# 19            NaT                CA                 NaN 2021-02-01       NaN
# 20            NaT                CA                 NaN 2021-02-01       NaN
# 21            NaT                CA                 NaN 2021-02-01       NaN
# 22            NaT                CA                 NaN 2021-02-01       NaN
# 23            NaT                CA                 NaN 2021-02-01       NaN
# 24            NaT                CA                 NaN 2021-02-01       NaN
# 25            NaT                CA                 NaN 2021-02-01       NaN
# 26            NaT                CA                 NaN 2021-02-01       NaN
# 27            NaT                CA                 NaN 2021-02-01       NaN
# 28            NaT                CA                 NaN 2021-02-01       NaN
# 29            NaT                CA                 NaN 2021-02-01       NaN
# ..            ...               ...                 ...        ...       ...
# 33            NaT                CA                 NaN 2021-02-01       NaN
# 34            NaT                CA                 NaN 2021-02-01       NaN
# 35            NaT                CA                 NaN 2021-02-01       NaN
# 36            NaT                CA                 NaN 2021-02-01       NaN
# 37            NaT                CA                 NaN 2021-02-01       NaN
# 38            NaT                CA                 NaN 2021-02-01       NaN
# 39            NaT                CA                 NaN 2021-02-01       NaN
# 40            NaT                CA                 NaN 2021-02-01       NaN
# 41            NaT                CA                 NaN 2021-02-01       NaN
# 42            NaT                CA                 NaN 2021-02-01       NaN
# 43            NaT                CA                 NaN 2021-02-01       NaN
# 44            NaT                CA                 NaN 2021-02-01       NaN
# 45     2020-01-01                CA                 NaN 2021-02-01       NaN
# 46            NaT                CA                 NaN 2021-02-01       NaN
# 47            NaT                CA                 NaN 2021-02-01       NaN
# 48            NaT                CA                 NaN 2021-02-01       NaN
# 49            NaT                CA                 NaN 2021-02-01       NaN
# 50            NaT                CA                 NaN 2021-02-01       NaN
# 51            NaT                CA                 NaN 2021-02-01       NaN
# 52            NaT                CA                 NaN 2021-02-01       NaN
# 53            NaT                CA                 NaN 2021-02-01       NaN
# 54            NaT                CA                 NaN 2021-02-01       NaN
# 55            NaT                CA                 NaN 2021-02-01       NaN
# 56     2020-01-01                CA                 NaN 2021-02-01       NaN
# 57            NaT                CA                 NaN 2021-02-01       NaN
# 58            NaT                CA                 NaN 2021-02-01       NaN
# 59            NaT                CA                 NaN 2021-02-01       NaN
# 60            NaT                CA                 NaN 2021-02-01       NaN
# 61            NaT                CA                 NaN 2021-02-01       NaN
# 62            NaT                CA                 NaN 2021-02-01       NaN
#
#     HourlyRate  AnnualPay PayCycle
# 0         14.5    4903.92   Weekly
# 1         14.5    4903.92   Weekly
# 2         14.5    4903.92   Weekly
# 3         14.5    4903.92   Weekly
# 4         14.5    4903.92   Weekly
# 5          NaN        NaN   Weekly
# 6         14.5    4903.92   Weekly
# 7         14.5    4903.92   Weekly
# 8         14.5    4903.92   Weekly
# 9         14.5    4903.92   Weekly
# 10        14.5    4903.92   Weekly
# 11        14.5    4903.92   Weekly
# 12         NaN        NaN   Weekly
# 13        14.5    4903.92   Weekly
# 14        14.5    4903.92   Weekly
# 15        14.5    4903.92   Weekly
# 16        14.5    4903.92   Weekly
# 17        14.5    4903.92   Weekly
# 18        14.5    4903.92   Weekly
# 19         NaN        NaN   Weekly
# 20        14.5    4903.92   Weekly
# 21        14.5    4903.92   Weekly
# 22        14.5    4903.92   Weekly
# 23        14.5    4903.92   Weekly
# 24        14.5    4903.92   Weekly
# 25        14.5    4903.92   Weekly
# 26        14.5    4903.92   Weekly
# 27        14.5    4903.92   Weekly
# 28        14.5    4903.92   Weekly
# 29         NaN        NaN   Weekly
# ..         ...        ...      ...
# 33        14.5    4903.92   Weekly
# 34        14.5    4903.92   Weekly
# 35         NaN        NaN   Weekly
# 36        14.5    4903.92   Weekly
# 37        14.5    4903.92   Weekly
# 38        14.5    4903.92   Weekly
# 39         NaN        NaN   Weekly
# 40        14.5    4903.92   Weekly
# 41         NaN        NaN   Weekly
# 42         NaN        NaN   Weekly
# 43        14.5    4903.92   Weekly
# 44         NaN        NaN   Weekly
# 45         NaN        NaN   Weekly
# 46        14.5    4903.92   Weekly
# 47        14.5    4903.92   Weekly
# 48         NaN        NaN   Weekly
# 49        14.5    4903.92   Weekly
# 50        14.5    4903.92   Weekly
# 51        14.5    4903.92   Weekly
# 52         NaN        NaN   Weekly
# 53        14.5    4903.92   Weekly
# 54         NaN        NaN   Weekly
# 55         NaN        NaN   Weekly
# 56         NaN        NaN   Weekly
# 57        14.5    4903.92   Weekly
# 58        14.5    4903.92   Weekly
# 59         NaN        NaN   Weekly
# 60        14.5    4903.92   Weekly
# 61        14.5    4903.92   Weekly
# 62        14.5    4903.92   Weekly
#
# [63 rows x 24 columns]
